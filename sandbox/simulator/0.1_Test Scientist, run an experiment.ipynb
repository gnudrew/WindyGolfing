# %% [markdown]
# # Test Scientist: Run an Experiment

# %%
from simulator.simulation.scientists import ExperimentRunner, ExperimentCollater
from simulator.models import SimExperiment
from winds.generators import OscillatoryGenerator
from commons.utilities import list_model_fields

import numpy as np
from numpy import pi

import requests

# %% [markdown]
# ## Load or Create Winds

# %% [markdown]
# Specify the wind parameters we want to use and load the corresponding winds trajectory if it exists, otherwise create it. We'll use the HTTP interface to do this, issuing commands via the appropriate *url* endpoints...

# %% [markdown]
# ### WindGenParams:

# %%
# wind velocity oscillating in XY-plane (Circle)
windgenparams = {
    'is_oscillatory': True,
    'base_velocity': np.array([0,0,0]), # not currently used for oscillatory
    'amplitude': np.array([1,1,0]),
    'frequency': np.array([1,1,1]),
    'phase_offset': np.array([0,np.pi/2,0]),
}

res = requests.post('http://localhost:8000/winds/wind-gen-params/', data=windgenparams)
res_data = res.json()
if res.status_code == 409:
    message = res_data['message']
    print(message)
else:
    print('Created.')
windgenparams_obj_id = res_data['id']
print(windgenparams_obj_id)
# Out:
# Already exists
# 26b671a4-cfe2-4931-829e-e7a780a48abb

# %% [markdown]
# ### WindSpacetime:

# %%
windspacetimeparams = {
    'generator_name': 'oscillatory',
    'generator_params': windgenparams_obj_id,
    'duration': 100,
    'timestep': .01,
}

res = requests.post('http://localhost:8000/winds/wind-spacetimes/', data=windspacetimeparams)
res_data = res.json()
windspacetime_obj_id = res_data['id']
print(res_data)
print(windspacetime_obj_id)
# Out:
# {'message': 'Already exists', 'id': '7bed9515-0a22-4516-a6b1-4f19923df74c'}
# 7bed9515-0a22-4516-a6b1-4f19923df74c

# %% [markdown]
# Great, we now have the UUID for a windspacetime specified by the parameters above. We now pass this id as a parameter to the scientist used to run the experiment.

# %% [markdown]
# ## Run Experiment

# %% [markdown]
# We'll call the scientist class directly until we setup an HTTP view to encapsulate this logic.

# %%
params = {
        'windgenparams_id': windgenparams_obj_id,
        'windspacetime_id': windspacetime_obj_id,
        'num_trials': 10,
        'timestep': 0.01,
        'prob_speed_fn_name': 'Uniform',
        'prob_speed_max': 42, # m/s
        'prob_speed_center': None,
        'prob_speed_spread': None,
        'prob_timing_fn_name': 'Uniform',
        'prob_timing_max': 1, # s
        'prob_timing_center': None,
        'prob_timing_spread': None,
        'prob_aiming_fn_name': 'Uniform',
        'prob_aiming_geometry': 'Spherical',
        'prob_aiming_X1_min': -pi/4,  # -45 deg
        'prob_aiming_X1_max': pi/4,   #  45 deg
        'prob_aiming_X1_center': None,
        'prob_aiming_X1_spread': None,
        'prob_aiming_X2_min': pi/6,   # 30 deg down from vertical 
        'prob_aiming_X2_max': 2*pi/3, # 120 deg down from vertical = 30 deg below horiztonal
        'prob_aiming_X2_center': None,
        'prob_aiming_X2_spread': None,
        'prob_aiming_X3_min': 0,      # throwaway coordinate
        'prob_aiming_X3_max': 1,
        'prob_aiming_X3_center': None,
        'prob_aiming_X3_spread': None,
}
runner = ExperimentRunner(params)
simtrial_ids = runner.run_experiment()
# Out:
# [Scientist] >>>>>>>>>>>>>> Running Trial #0 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 18
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [30.90362198  8.7679788  -7.08297326]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 1.08s.
# [SimTrialRunner] Ball hit ground.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [2.67325908e+01 8.58957289e+00 1.17155278e-02]
# [SimTrialRunner]   >> p2: [27.04666702  8.6826197  -0.1454422 ]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [26.75600404  8.59650919  0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] Saving Trial...
# [Scientist] fields:
# {'direction_initial': [0.9394631181931098,
#                        0.2665445723163671,
#                        -0.21532078516382028],
#  'position_final': [26.756004043837287, 8.596509186620533, 0.0],
#  'position_initial': [0, 0, 10],
#  'prob_aiming_X1_center': None,
#  'prob_aiming_X1_max': 0.7853981633974483,
#  'prob_aiming_X1_min': -0.7853981633974483,
#  'prob_aiming_X1_spread': None,
#  'prob_aiming_X2_center': None,
#  'prob_aiming_X2_max': 2.0943951023931953,
#  'prob_aiming_X2_min': 0.5235987755982988,
#  'prob_aiming_X2_spread': None,
#  'prob_aiming_X3_center': None,
#  'prob_aiming_X3_max': 1,
#  'prob_aiming_X3_min': 0,
#  'prob_aiming_X3_spread': None,
#  'prob_aiming_fn_name': 'Uniform',
#  'prob_aiming_geometry': 'Spherical',
#  'prob_speed_center': None,
#  'prob_speed_fn_name': 'Uniform',
#  'prob_speed_max': 42,
#  'prob_speed_spread': None,
#  'prob_timing_center': None,
#  'prob_timing_fn_name': 'Uniform',
#  'prob_timing_max': 1,
#  'prob_timing_spread': None,
#  'speed_initial': 32.89498158989858,
#  'time_initial': 0.17725752759155577,
#  'timestep': 0.01}
# [Scientist] Saved.
# [Scientist] v_i=[30.90362198  8.7679788  -7.08297326]m/s @ t_i=18 --> p_f=[26.75600404  8.59650919  0.        ]m.
# .
# [Scientist] >>>>>>>>>>>>>> Running Trial #1 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 42
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [10.71621949  1.59741706 -1.17142136]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 1.75s.
# [SimTrialRunner] Ball hit ground.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [14.94795816  2.83582613  0.11222301]
# [SimTrialRunner]   >> p2: [15.06263009  2.86653898 -0.0280022 ]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [15.03973073  2.8604058   0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] Saving Trial...
# [Scientist] fields:
# {'direction_initial': [0.9833408364055918,
#                        0.1465820504001783,
#                        -0.10749186926289231],
#  'position_final': [15.03973073397026, 2.8604057961588962, 0.0],
#  'position_initial': [0, 0, 10],
#  'prob_aiming_X1_center': None,
#  'prob_aiming_X1_max': 0.7853981633974483,
#  'prob_aiming_X1_min': -0.7853981633974483,
#  'prob_aiming_X1_spread': None,
#  'prob_aiming_X2_center': None,
#  'prob_aiming_X2_max': 2.0943951023931953,
#  'prob_aiming_X2_min': 0.5235987755982988,
#  'prob_aiming_X2_spread': None,
#  'prob_aiming_X3_center': None,
#  'prob_aiming_X3_max': 1,
#  'prob_aiming_X3_min': 0,
#  'prob_aiming_X3_spread': None,
#  'prob_aiming_fn_name': 'Uniform',
#  'prob_aiming_geometry': 'Spherical',
#  'prob_speed_center': None,
#  'prob_speed_fn_name': 'Uniform',
#  'prob_speed_max': 42,
#  'prob_speed_spread': None,
#  'prob_timing_center': None,
#  'prob_timing_fn_name': 'Uniform',
#  'prob_timing_max': 1,
#  'prob_timing_spread': None,
#  'speed_initial': 10.897767177248962,
#  'time_initial': 0.42331009816939646,
#  'timestep': 0.01}
# [Scientist] Saved.
# [Scientist] v_i=[10.71621949  1.59741706 -1.17142136]m/s @ t_i=42 --> p_f=[15.03973073  2.8604058   0.        ]m.
# .
# [Scientist] >>>>>>>>>>>>>> Running Trial #2 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 22
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [10.16892871 -3.36839271 12.95133694]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 3.5100000000000002s.
# [SimTrialRunner] Ball hit ground.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [32.49929273 -7.99576383  0.0625908 ]
# [SimTrialRunner]   >> p2: [32.58912794 -8.02025279 -0.12868283]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [32.52868966 -8.00377739  0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] Saving Trial...
# [Scientist] fields:
# {'direction_initial': [0.6050251468773701,
#                        -0.20041071726639534,
#                        0.7705712919975579],
#  'position_final': [32.528689660886975, -8.003777394464189, 0.0],
#  'position_initial': [0, 0, 10],
#  'prob_aiming_X1_center': None,
#  'prob_aiming_X1_max': 0.7853981633974483,
#  'prob_aiming_X1_min': -0.7853981633974483,
#  'prob_aiming_X1_spread': None,
#  'prob_aiming_X2_center': None,
#  'prob_aiming_X2_max': 2.0943951023931953,
#  'prob_aiming_X2_min': 0.5235987755982988,
#  'prob_aiming_X2_spread': None,
#  'prob_aiming_X3_center': None,
#  'prob_aiming_X3_max': 1,
#  'prob_aiming_X3_min': 0,
#  'prob_aiming_X3_spread': None,
#  'prob_aiming_fn_name': 'Uniform',
#  'prob_aiming_geometry': 'Spherical',
#  'prob_speed_center': None,
#  'prob_speed_fn_name': 'Uniform',
#  'prob_speed_max': 42,
#  'prob_speed_spread': None,
#  'prob_timing_center': None,
#  'prob_timing_fn_name': 'Uniform',
#  'prob_timing_max': 1,
#  'prob_timing_spread': None,
#  'speed_initial': 16.807448029243297,
#  'time_initial': 0.2158310906809875,
#  'timestep': 0.01}
# [Scientist] Saved.
# [Scientist] v_i=[10.16892871 -3.36839271 12.95133694]m/s @ t_i=22 --> p_f=[32.52868966 -8.00377739  0.        ]m.
# .
# [Scientist] >>>>>>>>>>>>>> Running Trial #3 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 45
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [ 3.02974678 -1.42431966 -0.13294409]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 1.8800000000000001s.
# [SimTrialRunner] Ball hit ground.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [ 5.43323419 -1.32524307  0.13007883]
# [SimTrialRunner]   >> p2: [ 5.47941647 -1.32869096 -0.00957161]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [ 5.47625114 -1.32845465  0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] Saving Trial...
# [Scientist] fields:
# {'direction_initial': [0.9042720551960169,
#                        -0.4251089497291373,
#                        -0.03967910094446935],
#  'position_final': [5.476251144288041, -1.3284546457604198, 0.0],
#  'position_initial': [0, 0, 10],
#  'prob_aiming_X1_center': None,
#  'prob_aiming_X1_max': 0.7853981633974483,
#  'prob_aiming_X1_min': -0.7853981633974483,
#  'prob_aiming_X1_spread': None,
#  'prob_aiming_X2_center': None,
#  'prob_aiming_X2_max': 2.0943951023931953,
#  'prob_aiming_X2_min': 0.5235987755982988,
#  'prob_aiming_X2_spread': None,
#  'prob_aiming_X3_center': None,
#  'prob_aiming_X3_max': 1,
#  'prob_aiming_X3_min': 0,
#  'prob_aiming_X3_spread': None,
#  'prob_aiming_fn_name': 'Uniform',
#  'prob_aiming_geometry': 'Spherical',
#  'prob_speed_center': None,
#  'prob_speed_fn_name': 'Uniform',
#  'prob_speed_max': 42,
#  'prob_speed_spread': None,
#  'prob_timing_center': None,
#  'prob_timing_fn_name': 'Uniform',
#  'prob_timing_max': 1,
#  'prob_timing_spread': None,
#  'speed_initial': 3.3504814830830503,
#  'time_initial': 0.4500521026084173,
#  'timestep': 0.01}
# [Scientist] Saved.
# [Scientist] v_i=[ 3.02974678 -1.42431966 -0.13294409]m/s @ t_i=45 --> p_f=[ 5.47625114 -1.32845465  0.        ]m.
# .
# [Scientist] >>>>>>>>>>>>>> Running Trial #4 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 66
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [33.8264704  -8.98684867 11.21956317]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 3.66s.
# [SimTrialRunner] Ball hit ground.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [ 1.02411898e+02 -2.93127016e+01  2.21052517e-02]
# [SimTrialRunner]   >> p2: [102.74914647 -29.40330819  -0.15803712]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [102.45328149 -29.32381989   0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] Saving Trial...
# [Scientist] fields:
# {'direction_initial': [0.9203426756811953,
#                        -0.24451207154114077,
#                        0.30525924423453266],
#  'position_final': [102.45328149090183, -29.323819886215805, 0.0],
#  'position_initial': [0, 0, 10],
#  'prob_aiming_X1_center': None,
#  'prob_aiming_X1_max': 0.7853981633974483,
#  'prob_aiming_X1_min': -0.7853981633974483,
#  'prob_aiming_X1_spread': None,
#  'prob_aiming_X2_center': None,
#  'prob_aiming_X2_max': 2.0943951023931953,
#  'prob_aiming_X2_min': 0.5235987755982988,
#  'prob_aiming_X2_spread': None,
#  'prob_aiming_X3_center': None,
#  'prob_aiming_X3_max': 1,
#  'prob_aiming_X3_min': 0,
#  'prob_aiming_X3_spread': None,
#  'prob_aiming_fn_name': 'Uniform',
#  'prob_aiming_geometry': 'Spherical',
#  'prob_speed_center': None,
#  'prob_speed_fn_name': 'Uniform',
#  'prob_speed_max': 42,
#  'prob_speed_spread': None,
#  'prob_timing_center': None,
#  'prob_timing_fn_name': 'Uniform',
#  'prob_timing_max': 1,
#  'prob_timing_spread': None,
#  'speed_initial': 36.75421263599103,
#  'time_initial': 0.6555954046702374,
#  'timestep': 0.01}
# [Scientist] Saved.
# [Scientist] v_i=[33.8264704  -8.98684867 11.21956317]m/s @ t_i=66 --> p_f=[102.45328149 -29.32381989   0.        ]m.
# .
# [Scientist] >>>>>>>>>>>>>> Running Trial #5 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 54
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [ 20.69566959 -17.34059073 -11.23582585]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 1.24s.
# [SimTrialRunner] Ball hit ground.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [ 14.92176369 -11.770639     0.12492042]
# [SimTrialRunner]   >> p2: [ 15.14028003 -11.95635468  -0.05414584]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [ 15.07420533 -11.9001982    0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] Saving Trial...
# [Scientist] fields:
# {'direction_initial': [0.7076732606067083,
#                        -0.5929487967171175,
#                        -0.3842008338017923],
#  'position_final': [15.074205326696568, -11.900198203333662, 0.0],
#  'position_initial': [0, 0, 10],
#  'prob_aiming_X1_center': None,
#  'prob_aiming_X1_max': 0.7853981633974483,
#  'prob_aiming_X1_min': -0.7853981633974483,
#  'prob_aiming_X1_spread': None,
#  'prob_aiming_X2_center': None,
#  'prob_aiming_X2_max': 2.0943951023931953,
#  'prob_aiming_X2_min': 0.5235987755982988,
#  'prob_aiming_X2_spread': None,
#  'prob_aiming_X3_center': None,
#  'prob_aiming_X3_max': 1,
#  'prob_aiming_X3_min': 0,
#  'prob_aiming_X3_spread': None,
#  'prob_aiming_fn_name': 'Uniform',
#  'prob_aiming_geometry': 'Spherical',
#  'prob_speed_center': None,
#  'prob_speed_fn_name': 'Uniform',
#  'prob_speed_max': 42,
#  'prob_speed_spread': None,
#  'prob_timing_center': None,
#  'prob_timing_fn_name': 'Uniform',
#  'prob_timing_max': 1,
#  'prob_timing_spread': None,
#  'speed_initial': 29.244668048699694,
#  'time_initial': 0.5428994028320109,
#  'timestep': 0.01}
# [Scientist] Saved.
# [Scientist] v_i=[ 20.69566959 -17.34059073 -11.23582585]m/s @ t_i=54 --> p_f=[ 15.07420533 -11.9001982    0.        ]m.
# .
# [Scientist] >>>>>>>>>>>>>> Running Trial #6 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 67
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [ 25.51760183 -22.38761275  19.4531624 ]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 5.12s.
# [SimTrialRunner] Ball hit ground.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [ 115.40363182 -102.84647769    0.13466645]
# [SimTrialRunner]   >> p2: [ 1.15671716e+02 -1.03084995e+02 -1.05384923e-01]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [ 115.55402414 -102.9802834     0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] Saving Trial...
# [Scientist] fields:
# {'direction_initial': [0.6522042825147497,
#                        -0.5722049044107018,
#                        0.49720329970522126],
#  'position_final': [115.5540241427826, -102.9802834034548, 0.0],
#  'position_initial': [0, 0, 10],
#  'prob_aiming_X1_center': None,
#  'prob_aiming_X1_max': 0.7853981633974483,
#  'prob_aiming_X1_min': -0.7853981633974483,
#  'prob_aiming_X1_spread': None,
#  'prob_aiming_X2_center': None,
#  'prob_aiming_X2_max': 2.0943951023931953,
#  'prob_aiming_X2_min': 0.5235987755982988,
#  'prob_aiming_X2_spread': None,
#  'prob_aiming_X3_center': None,
#  'prob_aiming_X3_max': 1,
#  'prob_aiming_X3_min': 0,
#  'prob_aiming_X3_spread': None,
#  'prob_aiming_fn_name': 'Uniform',
#  'prob_aiming_geometry': 'Spherical',
#  'prob_speed_center': None,
#  'prob_speed_fn_name': 'Uniform',
#  'prob_speed_max': 42,
#  'prob_speed_spread': None,
#  'prob_timing_center': None,
#  'prob_timing_fn_name': 'Uniform',
#  'prob_timing_max': 1,
#  'prob_timing_spread': None,
#  'speed_initial': 39.12516754463952,
#  'time_initial': 0.6673948067119674,
#  'timestep': 0.01}
# [Scientist] Saved.
# [Scientist] v_i=[ 25.51760183 -22.38761275  19.4531624 ]m/s @ t_i=67 --> p_f=[ 115.55402414 -102.9802834     0.        ]m.
# .
# [Scientist] >>>>>>>>>>>>>> Running Trial #7 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 27
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [13.40872397  4.16404515 -7.46052993]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 1.1400000000000001s.
# [SimTrialRunner] Ball hit ground.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [11.45074231  4.51711966  0.15637956]
# [SimTrialRunner]   >> p2: [ 1.15933726e+01  4.56183579e+00 -1.61073876e-03]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [11.59191843  4.5613799   0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] Saving Trial...
# [Scientist] fields:
# {'direction_initial': [0.8433448999569311,
#                        0.2618986152758846,
#                        -0.46923181374796863],
#  'position_final': [11.591918429910244, 4.561379903068196, 0.0],
#  'position_initial': [0, 0, 10],
#  'prob_aiming_X1_center': None,
#  'prob_aiming_X1_max': 0.7853981633974483,
#  'prob_aiming_X1_min': -0.7853981633974483,
#  'prob_aiming_X1_spread': None,
#  'prob_aiming_X2_center': None,
#  'prob_aiming_X2_max': 2.0943951023931953,
#  'prob_aiming_X2_min': 0.5235987755982988,
#  'prob_aiming_X2_spread': None,
#  'prob_aiming_X3_center': None,
#  'prob_aiming_X3_max': 1,
#  'prob_aiming_X3_min': 0,
#  'prob_aiming_X3_spread': None,
#  'prob_aiming_fn_name': 'Uniform',
#  'prob_aiming_geometry': 'Spherical',
#  'prob_speed_center': None,
#  'prob_speed_fn_name': 'Uniform',
#  'prob_speed_max': 42,
#  'prob_speed_spread': None,
#  'prob_timing_center': None,
#  'prob_timing_fn_name': 'Uniform',
#  'prob_timing_max': 1,
#  'prob_timing_spread': None,
#  'speed_initial': 15.899454619659055,
#  'time_initial': 0.2650878662535895,
#  'timestep': 0.01}
# [Scientist] Saved.
# [Scientist] v_i=[13.40872397  4.16404515 -7.46052993]m/s @ t_i=27 --> p_f=[11.59191843  4.5613799   0.        ]m.
# .
# [Scientist] >>>>>>>>>>>>>> Running Trial #8 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 26
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [22.20591614 -4.34252612 -1.48321454]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 1.56s.
# [SimTrialRunner] Ball hit ground.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [28.31011765 -4.43130675  0.12791739]
# [SimTrialRunner]   >> p2: [ 2.85231189e+01 -4.46226484e+00 -1.24827603e-02]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [28.50418128 -4.45951241  0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] Saving Trial...
# [Scientist] fields:
# {'direction_initial': [0.9793084009544335,
#                        -0.1915107794655471,
#                        -0.06541159811966892],
#  'position_final': [28.504181278015334, -4.459512405629434, 0.0],
#  'position_initial': [0, 0, 10],
#  'prob_aiming_X1_center': None,
#  'prob_aiming_X1_max': 0.7853981633974483,
#  'prob_aiming_X1_min': -0.7853981633974483,
#  'prob_aiming_X1_spread': None,
#  'prob_aiming_X2_center': None,
#  'prob_aiming_X2_max': 2.0943951023931953,
#  'prob_aiming_X2_min': 0.5235987755982988,
#  'prob_aiming_X2_spread': None,
#  'prob_aiming_X3_center': None,
#  'prob_aiming_X3_max': 1,
#  'prob_aiming_X3_min': 0,
#  'prob_aiming_X3_spread': None,
#  'prob_aiming_fn_name': 'Uniform',
#  'prob_aiming_geometry': 'Spherical',
#  'prob_speed_center': None,
#  'prob_speed_fn_name': 'Uniform',
#  'prob_speed_max': 42,
#  'prob_speed_spread': None,
#  'prob_timing_center': None,
#  'prob_timing_fn_name': 'Uniform',
#  'prob_timing_max': 1,
#  'prob_timing_spread': None,
#  'speed_initial': 22.675100219398985,
#  'time_initial': 0.25803400060129156,
#  'timestep': 0.01}
# [Scientist] Saved.
# [Scientist] v_i=[22.20591614 -4.34252612 -1.48321454]m/s @ t_i=26 --> p_f=[28.50418128 -4.45951241  0.        ]m.
# .
# [Scientist] >>>>>>>>>>>>>> Running Trial #9 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 69
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [ 9.24918088 -9.1554693  13.14363364]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 4.01s.
# [SimTrialRunner] Ball hit ground.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [ 31.86821687 -33.05961796   0.120406  ]
# [SimTrialRunner]   >> p2: [ 31.97437019 -33.15984251  -0.07188766]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [ 31.9346855  -33.12237425   0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] Saving Trial...
# [Scientist] fields:
# {'direction_initial': [0.5000469963425949,
#                        -0.4949805807283543,
#                        0.7105963876565726],
#  'position_final': [31.934685501255366, -33.12237425481214, 0.0],
#  'position_initial': [0, 0, 10],
#  'prob_aiming_X1_center': None,
#  'prob_aiming_X1_max': 0.7853981633974483,
#  'prob_aiming_X1_min': -0.7853981633974483,
#  'prob_aiming_X1_spread': None,
#  'prob_aiming_X2_center': None,
#  'prob_aiming_X2_max': 2.0943951023931953,
#  'prob_aiming_X2_min': 0.5235987755982988,
#  'prob_aiming_X2_spread': None,
#  'prob_aiming_X3_center': None,
#  'prob_aiming_X3_max': 1,
#  'prob_aiming_X3_min': 0,
#  'prob_aiming_X3_spread': None,
#  'prob_aiming_fn_name': 'Uniform',
#  'prob_aiming_geometry': 'Spherical',
#  'prob_speed_center': None,
#  'prob_speed_fn_name': 'Uniform',
#  'prob_speed_max': 42,
#  'prob_speed_spread': None,
#  'prob_timing_center': None,
#  'prob_timing_fn_name': 'Uniform',
#  'prob_timing_max': 1,
#  'prob_timing_spread': None,
#  'speed_initial': 18.496623209014693,
#  'time_initial': 0.6854318748956373,
#  'timestep': 0.01}
# [Scientist] Saved.
# [Scientist] v_i=[ 9.24918088 -9.1554693  13.14363364]m/s @ t_i=69 --> p_f=[ 31.9346855  -33.12237425   0.        ]m.
# .

# %% [markdown]
# ## Collate and Save Experiment

# %%
chunked_simtrial_ids = [simtrial_ids,]
collater = ExperimentCollater(params, chunked_simtrial_ids=chunked_simtrial_ids)
se_obj = collater.save_experiment()
se_obj_id = se_obj.id.__str__()
print(se_obj_id)
# Out:
# 673841a9-c3a3-46ac-b531-bb75cdd81382

# %% [markdown]
# ### Check saved experiment details

# %%
se_obj_check = SimExperiment.objects.get(pk=se_obj_id)
print(se_obj_check.num_trials)
print(se_obj_check.simtrials.all().count())
print(se_obj_check.prob_aiming_geometry)
# Out:
# 10
# 10
# Spherical

# %% [markdown]
# ## Chunkify the Experiment Run

# %% [markdown]
# Let's break the workload of computing `num_trials` SimTrials into chunks run across `num_workers` workers. For now, we'll do it "in series" for a quick test, but eventually we can convert this to "in parallel".

# %%
# add num_workers to params
params['num_workers'] = 2

# determine chunk size: runs_per_worker
num_trials = params['num_trials']
num_workers = params['num_workers']
runs_per_worker = int(num_trials/num_workers) # assume divisibility for now

# do runs
chunked_simtrial_ids = []
for _ in range(num_workers):
    worker_params = params.copy()
    worker_params['num_trials'] = runs_per_worker
    runner = ExperimentRunner(worker_params)
    simtrial_ids = runner.run_experiment()
    chunked_simtrial_ids.append(simtrial_ids)
    
print("chunked_simtrial_ids:")
print(chunked_simtrial_ids)

# collate chunks to single experiment
collater = ExperimentCollater(params, chunked_simtrial_ids=chunked_simtrial_ids)
se_obj = collater.save_experiment()

print("SimExperiment id:", se_obj)
# Out:
# [Scientist] >>>>>>>>>>>>>> Running Trial #0 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 6
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [25.24365961  1.56287109 -4.8927801 ]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 1.09s.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [24.56631972  1.94662436  0.1042421 ]
# [SimTrialRunner]   >> p2: [24.81850682  1.96167652 -0.0437667 ]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [24.74393424  1.95722554  0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] v_i=[25.24365961  1.56287109 -4.8927801 ]m/s @ t_i=6 --> p_f=[24.74393424  1.95722554  0.        ]m.
# .
# [Scientist] >>>>>>>>>>>>>> Running Trial #1 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 0
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [29.56883815 17.34014038 -9.70868983]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 0.76s.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [20.98746555 12.65762103  0.16588853]
# [SimTrialRunner]   >> p2: [ 2.12725260e+01  1.28410027e+01 -3.79236899e-03]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [21.26615493 12.83690412  0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] v_i=[29.56883815 17.34014038 -9.70868983]m/s @ t_i=0 --> p_f=[21.26615493 12.83690412  0.        ]m.
# .
# [Scientist] >>>>>>>>>>>>>> Running Trial #2 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 88
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [ 29.08168664 -13.46612801  19.34890577]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 5.3100000000000005s.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [125.303392   -62.5517596    0.15205445]
# [SimTrialRunner]   >> p2: [ 1.25584432e+02 -6.27029522e+01 -8.70774958e-02]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [125.48209428 -62.64789692   0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] v_i=[ 29.08168664 -13.46612801  19.34890577]m/s @ t_i=88 --> p_f=[125.48209428 -62.64789692   0.        ]m.
# .
# [Scientist] >>>>>>>>>>>>>> Running Trial #3 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 72
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [ 5.01401114 -5.00679682 -1.91915493]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 1.98s.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [ 6.56066405 -7.23887933  0.13914189]
# [SimTrialRunner]   >> p2: [ 6.62236381e+00 -7.29628327e+00 -1.69365695e-03]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [ 6.62162182 -7.29559295  0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] v_i=[ 5.01401114 -5.00679682 -1.91915493]m/s @ t_i=72 --> p_f=[ 6.62162182 -7.29559295  0.        ]m.
# .
# [Scientist] >>>>>>>>>>>>>> Running Trial #4 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 30
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [18.27399493  9.4650287   4.15459815]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 2.23s.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [35.49355278 19.98354299  0.13503746]
# [SimTrialRunner]   >> p2: [ 3.56818698e+01  2.00780180e+01 -1.07875545e-02]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [35.66793886 20.07102913  0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] v_i=[18.27399493  9.4650287   4.15459815]m/s @ t_i=30 --> p_f=[35.66793886 20.07102913  0.        ]m.
# .
# [Scientist] >>>>>>>>>>>>>> Running Trial #0 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 9
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [6.22116208 0.35422305 2.30729971]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 1.79s.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [8.79357692 1.37325012 0.11479551]
# [SimTrialRunner]   >> p2: [ 8.8485986   1.39207177 -0.0269395 ]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [8.83814066 1.38849435 0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] v_i=[6.22116208 0.35422305 2.30729971]m/s @ t_i=9 --> p_f=[8.83814066 1.38849435 0.        ]m.
# .
# [Scientist] >>>>>>>>>>>>>> Running Trial #1 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 44
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [10.22986907  1.13234611 14.61619724]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 4.0200000000000005s.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [39.66011971  5.64686734  0.04427217]
# [SimTrialRunner]   >> p2: [39.78171617  5.66187204 -0.15880185]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [39.68662896  5.65013851  0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] v_i=[10.22986907  1.13234611 14.61619724]m/s @ t_i=44 --> p_f=[39.68662896  5.65013851  0.        ]m.
# .
# [Scientist] >>>>>>>>>>>>>> Running Trial #2 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 33
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [ 8.2137596  -3.66399452 -4.91858596]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 1.36s.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [ 8.77765087 -2.82432778  0.07817818]
# [SimTrialRunner]   >> p2: [ 8.85924774 -2.86064794 -0.07008868]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [ 8.82067529 -2.84347868  0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] v_i=[ 8.2137596  -3.66399452 -4.91858596]m/s @ t_i=33 --> p_f=[ 8.82067529 -2.84347868  0.        ]m.
# .
# [Scientist] >>>>>>>>>>>>>> Running Trial #3 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 30
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [12.84402377  5.64405882 13.96081305]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 3.7600000000000002s.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [44.93512494 22.71662661  0.15012088]
# [SimTrialRunner]   >> p2: [45.06602744 22.79255803 -0.04773499]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [45.03444571 22.77423871  0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] v_i=[12.84402377  5.64405882 13.96081305]m/s @ t_i=30 --> p_f=[45.03444571 22.77423871  0.        ]m.
# .
# [Scientist] >>>>>>>>>>>>>> Running Trial #4 >>>>>>>>>>>>>>
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 9
#   >> p_initial    = [ 0  0 10]
#   >> v_initial    = [ 29.92207969 -19.73409208  20.62660874]
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 4.76s.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner]   >> p1: [ 1.34972041e+02 -8.94239277e+01  8.34506461e-02]
# [SimTrialRunner]   >> p2: [135.26219086 -89.60593013  -0.16644827]
# [SimTrialRunner] Interpolated.
# [SimTrialRunner]   >> p_final: [135.06893312 -89.48470519   0.        ]
# [SimTrialRunner] Run complete.
# [Scientist] v_i=[ 29.92207969 -19.73409208  20.62660874]m/s @ t_i=9 --> p_f=[135.06893312 -89.48470519   0.        ]m.
# .
# chunked_simtrial_ids:
# [[<SimTrial: SimTrial object (97fb6ff2-c5d5-4b67-9d98-535d616245de)>, <SimTrial: SimTrial object (3461efb3-b51e-4a67-b42d-4d3face36197)>, <SimTrial: SimTrial object (995fc8a0-8451-4e15-8dc8-8e6dcf4b5270)>, <SimTrial: SimTrial object (4ad6f228-8372-42c6-8f57-b801896ae026)>, <SimTrial: SimTrial object (79182316-081e-4fa2-84f8-f06f5e480052)>], [<SimTrial: SimTrial object (f4dd2ff1-5b17-4302-a48a-b42f42545360)>, <SimTrial: SimTrial object (f9a77d79-ff5c-43e1-8e08-e73b9a7595ab)>, <SimTrial: SimTrial object (12e792a4-b950-455a-8849-49320c581c59)>, <SimTrial: SimTrial object (024cd1e8-7741-41b1-b317-cdd5f0cf8db8)>, <SimTrial: SimTrial object (65e88e75-7915-4de3-91d5-c0b221ebd33e)>]]
# SimExperiment id: SimExperiment object (2166816a-378f-4246-82d0-0bc8218a02f3)
