# %% [markdown]
# # Testing Simulator

# %%
import numpy as np

from simulator.simulation.sim import SimTrialRunner

from winds.models import WindSpacetime
from winds.generators import OscillatoryGenerator

from commons.wranglers import BlobWrangler

# %% [markdown]
# ## Load a Windspacetime

# %% [markdown]
# ### filter for oscillatory wind spacetimes

# %%
# WindSpacetime.objects.all()

# %% [markdown]
# ### Set a wst_id

# %%
# wst_id = ''

# %% [markdown]
# ### wrangle df

# %%
# o = WindSpacetime.objects.get(pk=wst_id)
# df = BlobWrangler().read_blob(o)

# %% [markdown]
# ## Alternatively, generate a Windspacetime on the fly

# %%
# oscillate along x-axis only.
timestep = .01
params = {
    'base_velocity': np.array([0,0,0]),
    'amplitude': np.array([8,0,0]),
    'frequency': np.array([1,1,1]),
    'phase_offset': np.array([0,0,0]),
    'dt': timestep,
}
G = OscillatoryGenerator(params)
arr_wind_v = G.gen(10)
G.plot3d()
G.plotx()

# %%
arr_wind_v
# Out:
# array([[8.        , 0.        , 0.        ],
#        [7.98421383, 0.        , 0.        ],
#        [7.93691761, 0.        , 0.        ],
#        ...,
#        [7.93691761, 0.        , 0.        ],
#        [7.98421383, 0.        , 0.        ],
#        [8.        , 0.        , 0.        ]])

# %% [markdown]
# ## Run Simulation

# %% [markdown]
# ### Run simulator

# %%
# Set initial conditions
t_initial = 0
p_initial = np.array([0,0,20])
v_initial = np.array([20,0,10])
arr_windspacetime = arr_wind_v
timestep = timestep

# run
runner = SimTrialRunner(t_initial, p_initial, v_initial, arr_windspacetime, timestep)
runner.run()

# plot
runner.plotx()
runner.ploty()
runner.plotz()
runner.plot3d()
# Out:
# [SimTrialRunner] Preparing parameters...
# [SimTrialRunner] OK.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Run parameters are:
#   >> t_initial    = 0
#   >> p_initial    = [ 0  0 20]
#   >> v_initial    = [20  0 10]
#   >> windspeed_id =
#   >> timestep     = 0.01
#   >> g            = 9.81
#   >> m            = 0.0456
#   >> drag_coef    = 0
#   >> verbosity    = 1
# [SimTrialRunner] ====================================
# [SimTrialRunner] Running trial...
# [SimTrialRunner] Initializing ball trajectory...
# [SimTrialRunner] Initialized.
# [SimTrialRunner] ====================================
# [SimTrialRunner] Completed Run.
# [SimTrialRunner]  >> Ball hit ground?.. YES.
# [SimTrialRunner]  >> Trajectory duration = 3.3000000000000003s.
# [SimTrialRunner] Fin.
# [SimTrialRunner] Interpolating for final position between...
# [SimTrialRunner] p1: [40.65777074  0.          0.190932  ]
# [SimTrialRunner] p2: [ 4.07627802e+01  0.00000000e+00 -3.08360000e-02]
# [SimTrialRunner] Interpolated. p_final: [40.74817906  0.          0.        ]
